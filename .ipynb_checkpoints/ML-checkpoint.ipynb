# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from func import MlChart, PipeModel

# %%
dataset = pd.read_csv('Walmart_Sales.csv')
dataset.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
date = dataset['Date']
date.head()
# Out:
# 0    05-02-2010
# 1    12-02-2010
# 2    19-02-2010
# 3    26-02-2010
# 4    05-03-2010
# Name: Date, dtype: object

# %%
df = dataset.drop(dataset[['Store', 'Date']], axis = 1)
df.head()
# Out:
#    Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0    1643690.90             0        42.31       2.572  211.096358
# 1    1641957.44             1        38.51       2.548  211.242170
# 2    1611968.17             0        39.93       2.514  211.289143
# 3    1409727.59             0        46.63       2.561  211.319643
# 4    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment
# 0         8.106
# 1         8.106
# 2         8.106
# 3         8.106
# 4         8.106

# %%
X = df.iloc[:, 1:-1]
y = df.iloc[:, 0]
print(f'Dependent Variable \n{X.head()}\n')
print(f'Target \n{y.head()}\n')
# Out:
# Dependent Variable
#    Holiday_Flag  Temperature  Fuel_Price         CPI
# 0             0        42.31       2.572  211.096358
# 1             1        38.51       2.548  211.242170
# 2             0        39.93       2.514  211.289143
# 3             0        46.63       2.561  211.319643
# 4             0        46.50       2.625  211.350143
#
# Target
# 0    1643690.90
# 1    1641957.44
# 2    1611968.17
# 3    1409727.59
# 4    1554806.68
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# # Machine Learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression, Lasso, MultiTaskLassoCV

# %% [markdown]
# ## Split The Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.15,
                                                    random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.2,
                                                  random_state=42)

# Print the shape
print(f'Training batch shape X shape: {X_train.shape} target shape: {y_train.shape}')
print(f'Test batch shape X shape: {X_test.shape} target shape: {y_test.shape}')
print(f'Validation batch shape X shape: {X_val.shape} target shape: {y_val.shape}')
# Out:
# Training batch shape X shape: (4375, 4) target shape: (4375,)
# Test batch shape X shape: (966, 4) target shape: (966,)
# Validation batch shape X shape: (1094, 4) target shape: (1094,)

# %%
# Reshape the target
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values.reshape(-1, 1)
y_val = y_val.values.reshape(-1, 1)

# %%
models = [LinearRegression(), Lasso(), MultiTaskLassoCV()]
RunModels = PipeModel(models, 
                      X_train, y_train,
                      X_val, y_val)
RunModels
# Out:
# LinearRegression score: 1.1735%
# Lasso score: 1.1735%
# MultiTaskLassoCV score: 1.1105%
# /home/elysia/MyEnv/Project/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /home/elysia/MyEnv/Project/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /home/elysia/MyEnv/Project/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ## NN

# %%
from func import NeuralNetworkLinear, TrainingModel, ConvertToTensor
from torchmetrics.regression import MeanSquaredError
from torch.optim import Adam

# %%
X_train, X_val, X_test, y_train, y_val, y_test = ConvertToTensor(X_train, X_val, X_test,
                                                                 y_train, y_val, y_test)

# %%
model = NeuralNetworkLinear()

# %% [markdown]
# # Visualization

# %%
# Declare the models
for model in models:
    pipe = make_pipeline(StandardScaler(), model)
    pipe.fit(X_train, y_train)
    MlChart(model = pipe,
            X_train = X_train, 
            y_train = y_train,
            title = model,
            target = y_val, 
            prediction = X_val,
            LearningCurve=True)
